# %% [markdown]
# 1. What is NumPy and why is it important in data analysis?

# %% [markdown]
# Numpy is a module in python used in working with arrays and is important in data analysis for studying and analysing data

# %% [markdown]
# 2. State two advantages of NumPy over Python lists.

# %% [markdown]
# numpy arrays are more memory efficient, they are faster

# %% [markdown]
# 3. How do you create a NumPy array from a list?

# %% [markdown]
# You create an array from a list by typing 'array = numpy.array([1,2,3,4,5])'

# %% [markdown]
# 4. Differentiate between 1-D and 2-D arrays.

# %% [markdown]
# 1D arrays are made up of a collection of elements while 2D arrays are made up of a collection of 1D arrays

# %% [markdown]
# 5. How do you check the shape of an array?

# %% [markdown]
# You check the shape of an array by typing 'print(array.ndim)'

# %% [markdown]
# 6. Explain the use of array.size and array.ndim.

# %% [markdown]
# array.size displays the total number of elements in an array, array.ndim displays the number of dimensions of the array

# %% [markdown]
# 7. How do you create an array filled with zeros?

# %% [markdown]
# You create an array with zeros by using the 'np.zeros()' function

# %% [markdown]
# 8. What is broadcasting in NumPy?

# %% [markdown]
# Broadcasting is the act of performing arithmetic operations on arrays of different shapes.

# %% [markdown]
# 9. Perform element-wise addition on two arrays.

# %%
import numpy as np
arr1 = np.array([1, 2, 3, 4])
arr2 = np.array([5, 6, 7, 8])
A = arr1 + arr2
print(A)
# Out:
# [ 6  8 10 12]

# %% [markdown]
# 10. What happens when arrays have incompatible shapes?

# %% [markdown]
# If their shapes are not compatible, it will raise a value error and fail to broadcast them together

# %% [markdown]
# 11. Explain array slicing with an example.

# %%
# Array slicing is the act of extracting specific elements from an array
arr1 = np.array([1, 2, 3, 4])
print(arr1[1:3])
# Out:
# [2 3]

# %% [markdown]
# 12. How do you reshape an array?

# %% [markdown]
# You reshape an array by using 'array.reshape()

# %% [markdown]
# 13. Differentiate between copy and view in NumPy.

# %% [markdown]
# copy creates a new array with the same data while view is an array that shares the same memory

# %% [markdown]
# 14. How do you compute mean and standard deviation?

# %% [markdown]
# mean is calculated using 'np.mean()' and standard deviation is calculated using 'np.std()'

# %% [markdown]
# 15. Explain matrix multiplication in NumPy.

# %% [markdown]
# matrix multiplication is performed using np.dot(), A @ B, np.matmul(), np.multiply. The method used depends on the data or result needed

# %% [markdown]
# 16. Difference between np.dot() and np.multiply().

# %% [markdown]
# np.dot() performs dot product between matrixes, that is the first row of the first matrix multiplied by the first column of the second matrix.
#
# While np.multiply() performs element wise multiplication

# %% [markdown]
# 17. How do you filter values using conditions?

# %% [markdown]
# Filtering is done using boolean indexing and comparison operators

# %% [markdown]
# 18. How does NumPy handle NaN values?

# %% [markdown]
# nan values can be checked using isnan() function

# %% [markdown]
# 19. Explain np.arange() and np.linspace().

# %% [markdown]
# they are both used to create arrays of values with equal spaces.
#
# np.arange specifies the step size
#
# while np.linspace specifies the number of elements in the array

# %% [markdown]
# 20. Mention two real-life applications of NumPy.

# %% [markdown]
# It is used in data analysis and machine learning
